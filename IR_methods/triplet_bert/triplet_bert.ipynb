# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import sys
sys.path.append('../../../../')
from sentence_transformer_custom import SentenceTransformerCustom
import config
# Out:
# c:\Users\EE303\anaconda3\envs\pytorch_gpu\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# #### Step 1 - Load data

# %%
# product item
item_df = pd.read_parquet('../PChome_datasets/search/pchome_test_collection/round0/product_collection/product_collection_lg.parquet')

# load test query
# test_query_df = pd.read_csv('../PChome_datasets/search/pchome_test_collection/round1/test_query/test_query_250.csv') # round0 test query
# test_query_df = pd.read_csv('../PChome_datasets/search/pchome_test_collection/round1/test_query/test_query_250.csv') # round1 test query

# load valid query
test_query_df = pd.read_csv('../PChome_datasets/search/pchome_test_collection/round1/valid_query/valid_query_200.csv')

# %%
# -------------------------------------------------------
#   Get product embeddings
# -------------------------------------------------------
print('Get product embeddings ...')
product_collection_size = 'lg' # 'sm' or 'lg'

# get product embeddings sm
if product_collection_size == 'sm':
    product_collection_sm_df = pd.read_parquet(config.product_collection_sm_path)
    name_sentences = product_collection_sm_df['name'].to_list()
    product_embeddings = model.encode(
        sentences=name_sentences,
        batch_size=128,
        normalize_embeddings=True,
        show_progress_bar=True,
    )
elif product_collection_size == 'lg':
    product_collection_lg_df = pd.read_parquet(config.product_collection_lg_path)
    # from npy array file
    product_embeddings = np.load(config.save_model_path + '/eval_reports/test_collection_lg/product_embeddings.npy')
# Out:
# Get product embeddings ...

# %% [markdown]
# #### Step 2 - Build model

# %%
# -------------------------------------------------------
#   Model
# -------------------------------------------------------
# init model
print('Experiment name:', config.exp_name)
model = SentenceTransformerCustom(config.save_model_path)
# Out:
# Experiment name: bert_soft-margin-triplet-loss_train-lg_intent-based-neg-2

# %% [markdown]
# #### Step 3 - Search function

# %%
def search(query):
    # get test query embeddings
    query_embeddings = model.encode(
        sentences=[query],
        batch_size=128,
        normalize_embeddings=True,
    )

    # get query result lists
    scores = np.dot(query_embeddings, product_embeddings.T)
    top_50_indices = np.argsort(-scores)[:,:50]
    # result_df = product_collection_lg_df[product_collection_lg_df.index.isin(top_50_indices[0])].reindex(top_50_indices[0])
    result_df = item_df.loc[top_50_indices[0]]
    return result_df

# %%
search("vga轉hdmi")
# Out:
#                   item_id                                               name
# 1056473  DCACYC-A900B0DKC                                     HDMI TO VGA轉接線
# 335168   DCACRX-A90099ESR                 HDMI轉VGA轉接線-1.8米 HDMI(公) TO VGA(公)
# 576210   DCACYC-A900BEGL4                                      HDMI轉VGA接頭 黑色
# 193532   DRAD5V-A90066HU3                                VGA(公)轉HDMI(母)影音轉接線
# 789845   CAAQ12-A74419917                                        VGA轉HDMI轉換器
# 709574   DCACYC-A900BCSA1                                      HDMI轉VGA接頭 白色
# 2009483  DCACRJ-A9008MNCX                     HDMI(公) to VGA(母) 視頻轉接線 轉接器-黑色
# 464535   DMAA2K-A9008WYMY                           VGA(公)轉HDMI(母) 訊號影音傳輸轉接器
# 1913648  DCACRJ-A9008MNCK                     HDMI(公) to VGA(母) 視頻轉接線 轉接器-白色
# 455184   DMAA2K-A900AEJDO                      (5年保固) 嚴選 HDMI TO VGA視頻轉接線(黑)
# 1913312  DCACZB-A900A8U1V                          1080P高解析 HDMI轉VGA連接線 1.8M
# 514557   DCACYC-A90096RAE                           HDMI (公) 轉 VGA (母) 1080p
# 654124   QABB3J-A9009OJ3T                         Esense HDMI TO VGA 免電源 轉接器
# 44561    DMAA3W-A900ACPG8                      VGA(公)轉HDMI(母) 訊號影音傳輸轉接器-15cm
# 600869   DCAJDZ-A90084MJR                       HDMI to VGA 視頻轉接線(2入組/黑)15CM
# 162608   DMAA2K-A900B8TRI        HDMI轉VGA轉接線-1.8米 音源輸出 HDMI(公) TO VGA(公)-音源版
# 833470   DCACFD-A900BMM0V             UniSync HDMI公轉VGA母高畫質1080P鍍金轉接器 黑/15CM
# 925841   DMAA2K-A9009XKWN                    HDMI(母) 轉 VGA(公) 訊號影音傳輸轉接器 帶音頻線
# 13979    DMAA3W-A900A67LV                 HDMI(公)轉VGA(公) 訊號影音傳輸轉接線 帶音頻線 1.5M
# 923762   DCACYC-A9008IDZY                          HDMI to VGA 轉接線-Adapter01
# 1251150  DCACQ8-A9007SV5L                            HDMI 轉 VGA 轉接器 轉接線 帶音頻線
# 2183247  DCAC6L-A63594364                                      HDMI轉VGA 10cm
# 118552   QABB3J-A90097E8W                    HDMI TO VGA 高清視訊轉接器 / 轉接頭 / 轉接線
# 246449   AGAD45-A9005IXSV                          頂級整合型 HDMI 轉 VGA 轉換器含聲音輸出
# 1992793  DCACRJ-A9008NZHM                     HDMI(母) 轉 VGA(母)影像影音轉換轉接器 附音源線
# 1429815  DSAJ2B-A9007CK3G                                  HDMI轉VGA【帶音頻、供電線】
# 1460071  DCACLL-A900ANX98                       Type-C轉4KX2K HDMI與VGA轉接線(1入)
# 1472954  DCADJ5-A900AZG22                                 Type-C轉HDMI VGA轉接線
# 1470428  DCAM0N-A90051NM4  VGA轉HDMI轉換器 VGA TO HDMI 1080P 影音同步 高清轉換器轉接器 (5...
# 645725   QBAA4N-A9009F6F8                                             VGA轉換器
# 1010184  QABF16-A900AROYR                               【伽利略】HDMI TO VGA 轉接線
# 184939   DCADJ5-A900BT5UM                    Type-C轉VGA+HDMI4K高畫質影音轉接器-鋁合金材質
# 276955   DCACPQ-A900AC6QG          HDMI 轉 VGA 訊號轉換器 適用HDMI端口筆電及桌機轉VGA顯示器/投影機
# 1210889  DCACZQ-A9008LSCB                          HDMI(公) TO VGA adapter(母)
# 426385   DCAX07-A900ALORJ                                    伽利略 HDMI to VGA
# 1344502  DCAC5A-A9008FX7M                                          DP轉VGA轉接器
# 1069064  DCACQ3-A9008MXSN                TYPE-C TO HDMI  VGA 電腦專用高畫質影音轉接線(銀)
# 265493   DCACYC-A900BMLWI               UniSync HDMI公轉VGA母/3.5mm高畫質影像鍍金轉接頭 黑
# 2226831  QAAB1F-A9007SWI5                       HDMI 轉 VGA 轉接器 轉接線 附3.5mm音頻線
# 24511    DCACYC-A900BQ463  HDMI轉VGA投影+3.5mm音源 二合一Hub投影轉接器 支援HDMI轉VGA投影+3....
# 1342012  DCACGJ-A900ALRMX                          L-CUBIC 轉接線/HDMI公轉VGA母/黑色
# 383172   DSAJ45-A9008HBI4                   HDMI(公) to VGA(母) 鍍金接頭轉接器15cm(黑)
# 1362581  DCACYC-A900BMLT0               UniSync HDMI公轉VGA母/3.5mm高畫質影像鍍金轉接頭 白
# 1505897  DCACGJ-A900ALRMI                          L-CUBIC 轉接線/HDMI公轉VGA母/白色
# 333834   DCAC9C-A64467155                          fujiei HDMI TO VGA 免電源轉換線
# 1922068  DCACPG-A90096F06                  Type-C轉VGA+HDMI 二合一 4K高畫質鋁合金影音轉接器
# 1712235  DCACSY-A900A11ZL                      VGA(公)轉HDMI(母) 電腦影像投影轉換器 帶音頻線
# 98801    DMAA6A-A900AIX0J                                     VGA TO AV視訊轉接盒
# 207788   DCACYC-A900BMKHL           UniSync HDMI轉VGA/3.5mm高畫質1080P影像轉接器 附音源線
# 2073298  DCACYC-A900B7ZDV  HDMI 轉 VGA 線 投影機 電腦 傳輸線 鍍金接頭 線材 HDMI轉接器 電視 螢幕 ...

# %% [markdown]
# #### Step 4 - Output search results for test queries

# %%
for i, r in tqdm(enumerate(test_query_df.iloc)):
    query = r['query']
    results = search(query)
    # results = results.drop('sign_id', axis=1).reset_index(drop=True)

    # save result files for pooling step(id start from 250)
    results.to_parquet('./dataset_process/test_collection_round1/runs/triplet_bert/results/results_round1_valid_query/result_'+str(r['query_id']).zfill(3)+'.parquet')
# Out:
# 200it [02:16,  1.47it/s]

# %% [markdown]
# #### sandbox

# %%
N = 0
print("query: ", test_query_df['query'][N])
result_df = pd.read_parquet('./dataset_process/test_collection_round1/runs/triplet_bert/results/results_round1_valid_query/result_'+str(N).zfill(3)+'.parquet')
result_df
# Out:
# query:  文具
#                   item_id                                   name
# 1506439  DJAV0S-A90080KTK                           最新便利文具用品特選專集
# 562018   DJAH0H-A75182816        文具病：愛文具、玩文具、品文具，以文具傳達生活態度的25種可能
# 1300558  DJAH2O-A81683547                   日本最新實用便利個性文具商品特選2014
# 622818   DJAH2O-A9007YQWI                    趣味文具大集合 VOL.41：文具贈禮
# 1668611  DJAH0H-A9008A35F                      文具的品格：全球經典文具的深度巡禮
# 1248965  DEAHFY-A9006XKAO                   磁鐵書籤 - 文具系列 【STUDIO】
# 1512382  DJAP4E-A900AI84T                       實用文具用品完全精選圖鑑 最新版
# 1582321  DJAH2O-A9005YQ1O                           文具用品便利生活特選專集
# 648737   DJAH2O-A9005N6QJ                   趣味文具大集合 VOL.30：文具的快樂
# 118533   DEAHFY-A9006XK9Y                   磁鐵書籤 - 文具系列 【SCHOOL】
# 556836   DJAH07-A26629115                              世界好文具(01)
# 1537804  DEAHFY-A9006XKAX                    磁鐵書籤 - 文具系列 【CRAFT】
# 1601999  DJAH2O-A9005T9CH                   日本最新實用便利個性文具商品特選2015
# 1533290  DJAH2O-A90069J72                         趣味文具大集合 VOL.34
# 5872     DJAP4E-A9008NG41                         趣味文具大集合 VOL.44
# 682937   DJAH2O-A9006JPXZ                         趣味文具大集合 VOL.35
# 1520860  DJAP4E-A900A5LOX                         趣味文具大集合 VOL.50
# 1227808  DJAH2O-A9005ZFF6                    趣味文具大集合 VOL.33：鋼筆特集
# 984187   DJAP4E-A9008VZ3Q                         趣味文具大集合 VOL.45
# 791549   DJAH2O-A9005MF0R                  趣味文具大集合 VOL.31：鋼筆書寫特集
# 1714722  DJAP4E-A9009OSCI                         趣味文具大集合 VOL.48
# 309930   DJAH2O-A90051K9M                     年度特選最佳實用文具款式大賞2014
# 2155091  DJAP4E-A900A9YOX                         趣味文具大集合 VOL.51
# 1750244  DJAP47-A9006KLKF                                  書寫的工具
# 398892   DJAP4E-A900AFSH8                         趣味文具大集合 VOL.52
# 1306687  DJAH2O-A9005511R                  文具設計造型完全圖鑑 NO.10：文具物語
# 358490   DJAH2O-A80846680                         趣味文具大集合 VOL.23
# 1876073  DEAF2E-A900659Z5                  力大ABEL絕色漾彩文具組09912/藍色
# 1223169  DJAP4E-A9009VRA3                         趣味文具大集合 VOL.49
# 1665265  DJAH2O-A78348963                        文具設計造型完全圖鑑 NO.9
# 1290062  DJAP4E-A9009Y6G9                       百元商店文具用品最佳選購完全專集
# 1548390  DJAH2O-A9007LUU6                         趣味文具大集合 VOL.39
# 2152653  DJAP4E-A9009GIIV                         趣味文具大集合 VOL.47
# 54113    DJAH2O-A9007BUE2                         趣味文具大集合 VOL.38
# 1075581  DJAP4E-A900AJF1V                     年度特選最佳實用文具款式大賞2020
# 1898034  DJAH2O-A77833279                         趣味文具大集合 VOL.24
# 1502860  DJAP4E-A900961OU                         趣味文具大集合 VOL.46
# 2158138  DJAH2O-A9008F7CS                         趣味文具大集合 VOL.43
# 1755694  DJAH2O-A9005VWFH                         我的最愛文具款式大賞圖鑑專集
# 1701909  DJAH0H-A90081WKS             仕事文具：文具職人嚴選，激發創意與效率的235項利器
# 507640   DEAHR5-A900B75QA                   KOKUYO KOKUYO 職人文具套組
# 1419342  DJAH1I-A55932550                             手縫皮革文具(平裝)
# 1760497  DEAHD6-A9009VQRA             【ABEL】【自然風】A4原色板夾手繪系列-經典文具
# 380567   QFBU10-A900AES3E           1組六入 無印簡約風 透明磨砂中性筆 文具 辦公室 開學
# 1378767  DJAH2O-A78710355                    趣味文具大集合 VOL.26：鋼筆特集
# 522924   DJAH2O-A9007LUU2                          便利筆記文具特選大圖鑑專集
# 2057639  DJAG0N-A900B689G                     年度特選最佳實用文具款式大賞2021
# 745096   DEAHLL-A900BBJ0Q  小魚行銷 辦公文具系列 0.5mm中性筆50隻及替換筆芯120隻 任選4組
# 1552386  DEAH93-A900AFDLQ                       復古色系文具套裝4件組_奢華金純
# 1743283  DEBUAL-A900BCIZ9                          塑膠A4文件夾手寫板 橘色

# %%
import random
N = random.randint(0,99)
print("N: ", N)
# Out:
# N:  97
