# %%
from tqdm import tqdm
import re

import numpy as np
import pandas as pd
from gensim.summarization import bm25

# %% [markdown]
# #### Step 1 - Load data

# %%
# # load test query
# test_query_df = pd.read_csv('../../../../../PChome_datasets/search/pchome_test_collection/round1/test_query/test_query_250.csv')

# load valid query
test_query_df = pd.read_csv('../../../../../PChome_datasets/search/pchome_test_collection/round1/valid_query/valid_query_200.csv')

# product item
item_df = pd.read_parquet('../../../../../PChome_datasets/search/pchome_test_collection/round0/product_collection/product_collection_lg.parquet')

# %% [markdown]
# #### Step 2 - Build model

# %%
# 1. method 2: chinese char and english word
def ch_char_en_word_tokenizer(x):
    # to lower case
    x = x.lower()
    # chinese char and english word
    pattern = re.compile(r'([\u4E00-\u9FFF]|[A-Za-z0-9\°]+(\-*[A-Za-z0-9\°]*)*)')
    results = re.findall(pattern, x)
    results = [x[0] for x in results]
    return results

# english word digit tokenizer
def en_word_digit_tokenizer(x):
    # to lower case
    x = x.lower()
    pattern = re.compile(r'([A-Za-z]+|[0-9]+)')
    results = re.findall(pattern, x)
    return results

# convert name to tokenized name
tokenized_items = item_df['name'].map(ch_char_en_word_tokenizer).to_list()

# %%
# 2. bm25 model
bm25Model = bm25.BM25(tokenized_items)

# %% [markdown]
# #### Step 3 - Search function

# %%
def search(query):
    # jieba tokenizer
    # scores = np.array(bm25Model.get_scores(jieba.lcut(query, cut_all=True)))

    # ch_char_en_word_tokenizer
    scores = np.array(bm25Model.get_scores(ch_char_en_word_tokenizer(query)))

    # nothing found by ch_char_en_word_tokenizer, alternative solution: en_word_digit_tokenizer
    if scores.sum() == 0:
        print(query)
        scores = np.array(bm25Model.get_scores(en_word_digit_tokenizer(query)))
    
    top_50_indices = np.argsort(-scores)[:50]
    return top_50_indices

# %% [markdown]
# #### Step 4 - Output search results for test queries

# %%
for r in tqdm(test_query_df.iloc):
    top_50_indices = search(r['query'])
    results = item_df[item_df.index.isin(top_50_indices)].reindex(top_50_indices)
    results.reset_index(drop=True, inplace=True)
    
    # save result files for pooling step(id start from 250)
    results.to_parquet('./results/results_round1_valid_query/result_'+str(r['query_id']).zfill(3)+'.parquet')
# Out:
# 125it [01:59,  1.01s/it]
# 5300u
# 189it [03:07,  1.06s/it]
# lr6egt
# 197it [03:17,  1.10s/it]
# ef-1268ba
# 200it [03:21,  1.01s/it]

# %% [markdown]
# #### Sanbox

# %%
# search for assigned query
query = test_query_df['query'][0]
top_50_indices = search(query)
item_df.loc[top_50_indices]
# Out:
#                   item_id                                             name
# 562018   DJAH0H-A75182816                  文具病：愛文具、玩文具、品文具，以文具傳達生活態度的25種可能
# 1489649  DJAP0T-A42169844                                  故宮文物寶藏文具篇：文具的故事
# 2093540  DJAH0H-A82260802                            文具手帖Season04：好色文具強迫症！
# 622818   DJAH2O-A9007YQWI                              趣味文具大集合 VOL.41：文具贈禮
# 712380   DJAH0H-A9007LDDB                                文具手帖：台灣文具屋散策（熄燈號）
# 648737   DJAH2O-A9005N6QJ                             趣味文具大集合 VOL.30：文具的快樂
# 1874143  DJAH0H-A900A9T3K  文房具解剖圖鑑：23款經典文具「進化論」，圖解文具的構造、形狀、演變歷程，譜出浪漫文具文化史！
# 203575   DJAP06-A9007KZYS                               文具手帖（1～4）文具好朋友勸敗套書
# 1177395  DJAP06-A9007L011                               文具手帖（5～8）文具偏執狂必藏套書
# 438940   DJAM0H-A68469142                                           戀：文具物語
# 1274449  DEAHM3-A9007H88Q                                            文具置物盤
# 762168   DJAF0D-A76754434                                            文具精靈國
# 1306687  DJAH2O-A9005511R                            文具設計造型完全圖鑑 NO.10：文具物語
# 1070195  QFCD25-D900915ZA                      文具手帖Season 04：好色文具強迫症！（電子書）
# 1228319  DJAH2O-A9006F0IA                                文具王高?正幸究極文具插畫圖鑑手冊
# 1668611  DJAH0H-A9008A35F                                文具的品格：全球經典文具的深度巡禮
# 2151032  DJAH2O-A9005EOX0                                達人最愛文具＆特選文具店鋪導覽讀本
# 1215075  DJAH0H-A90080ZPM                    好文具帶來好生活！銀座?伊東屋文具 BETTER LIFE
# 488678   QFCD25-D900915XV                           文具手帖（熄燈號）：臺灣文具屋散策（電子書）
# 1737928  DJAH0H-A9008A35D                              文具上手：12位專業人士活用文具的靈光
# 938905   DEACDQ-A9005EWNE                                 NUSHARP 205 文具剪刀
# 556836   DJAH07-A26629115                                        世界好文具(01)
# 458980   DEACDQ-A9005EWND                                 NUSHARP 203 文具剪刀
# 1875355  DSACSD-A9007FT7F                                          文具膠帶3/4
# 1395621  DJAM07-A9008A6JX                                           山茶花文具店
# 1488522  DJAH0H-A9005R8MW                            大人的文具500選：藏家必蒐設計經典文房具
# 921720   DJAH0H-A9005TUIL                          此生必逛的日本文具屋39選＋嚴選文房具40款！
# 1113920  DCBD9W-B900AVW8A                                     新人文具包 (100份)
# 2014893  DJAF06-A900B80NF                                        文具大逃亡(精裝)
# 1970312  DEAHR5-A900BNA9W                                   KOKUYO 開學文具組-綠
# 1436762  DEAHR5-A900BNA9F                                   KOKUYO 開學文具組-粉
# 775879   DEAHXL-A9008QDGC                                       LEGO積木文具組A
# 308384   DEAH6R-A900B3VJE                              PLUS team-demi磁吸文具組
# 2656     DEAE9F-A9008VLIA                                          桌上文具收納盒
# 29521    DICKA0-A900B4LU9                                          彩色圖騰文具盒
# 1925702  QABH04-B900A9SD6                                      新人文具包 (60份)
# 1940230  DEAHR5-A900BNA9R                                   KOKUYO 開學文具組-藍
# 704929   DSACMT-A90063A01                                  炎洲文具膠帶-18mmX45Y
# 726996   QFAM2V-A9006C2RV                             文具筒台燈(ZE-9-1~ZE-9-5)
# 161955   DEAH4D-A67993156                                        文具膠帶台 -1入
# 1793325  DEAHEE-A900ACAD4                                     15公分文具尺-2PCS
# 1203625  DEAHEE-A900ACAE6                                     60公分文具尺-1PCS
# 385620   DEAHEE-A900C0OO7                                     30公分文具尺-4PCS
# 1553797  DEBAQX-B900BAQT8                                          木製文具收納盒
# 1889928  CCAA46-B39912565                                          專用文具鍵盤架
# 1100915  DJAH0H-A90057SJG                                          京都的文具時光
# 1758920  QFBU8V-A9009LPY2                                      文具店 TAG 裹葉色
# 1105319  QFBU0J-A900AGL0N        1組四入 日常計畫備忘貼 便利貼 標籤貼 N次貼 便條紙 辦公文具 開學文具 文具
# 1917895  QFAD4Y-A900ASCP1           【FL生活+】桌面抽屜式多功能文件文具收納盒系列-文具收納款(YG-069)
# 1049695  QFBU0Z-A900AG731  1組四入 快樂麋鹿中性筆 針管筆 0.35mm 黑色 原子筆 文具 開學文具 辦公文具 聖誕節

# %%
N = 0
print("query: ", test_query_df['query'][N])
result_df = pd.read_parquet('./results/results_round1_valid_query/result_'+str(N).zfill(3)+'.parquet')
result_df
# Out:
# query:  文具
#              item_id                                             name
# 0   DJAH0H-A75182816                  文具病：愛文具、玩文具、品文具，以文具傳達生活態度的25種可能
# 1   DJAP0T-A42169844                                  故宮文物寶藏文具篇：文具的故事
# 2   DJAH0H-A82260802                            文具手帖Season04：好色文具強迫症！
# 3   DJAH2O-A9007YQWI                              趣味文具大集合 VOL.41：文具贈禮
# 4   DJAH0H-A9007LDDB                                文具手帖：台灣文具屋散策（熄燈號）
# 5   DJAH2O-A9005N6QJ                             趣味文具大集合 VOL.30：文具的快樂
# 6   DJAH0H-A900A9T3K  文房具解剖圖鑑：23款經典文具「進化論」，圖解文具的構造、形狀、演變歷程，譜出浪漫文具文化史！
# 7   DJAP06-A9007KZYS                               文具手帖（1～4）文具好朋友勸敗套書
# 8   DJAP06-A9007L011                               文具手帖（5～8）文具偏執狂必藏套書
# 9   DJAM0H-A68469142                                           戀：文具物語
# 10  DEAHM3-A9007H88Q                                            文具置物盤
# 11  DJAF0D-A76754434                                            文具精靈國
# 12  DJAH2O-A9005511R                            文具設計造型完全圖鑑 NO.10：文具物語
# 13  QFCD25-D900915ZA                      文具手帖Season 04：好色文具強迫症！（電子書）
# 14  DJAH2O-A9006F0IA                                文具王高?正幸究極文具插畫圖鑑手冊
# 15  DJAH0H-A9008A35F                                文具的品格：全球經典文具的深度巡禮
# 16  DJAH2O-A9005EOX0                                達人最愛文具＆特選文具店鋪導覽讀本
# 17  DJAH0H-A90080ZPM                    好文具帶來好生活！銀座?伊東屋文具 BETTER LIFE
# 18  QFCD25-D900915XV                           文具手帖（熄燈號）：臺灣文具屋散策（電子書）
# 19  DJAH0H-A9008A35D                              文具上手：12位專業人士活用文具的靈光
# 20  DEACDQ-A9005EWNE                                 NUSHARP 205 文具剪刀
# 21  DJAH07-A26629115                                        世界好文具(01)
# 22  DEACDQ-A9005EWND                                 NUSHARP 203 文具剪刀
# 23  DSACSD-A9007FT7F                                          文具膠帶3/4
# 24  DJAM07-A9008A6JX                                           山茶花文具店
# 25  DJAH0H-A9005R8MW                            大人的文具500選：藏家必蒐設計經典文房具
# 26  DJAH0H-A9005TUIL                          此生必逛的日本文具屋39選＋嚴選文房具40款！
# 27  DCBD9W-B900AVW8A                                     新人文具包 (100份)
# 28  DJAF06-A900B80NF                                        文具大逃亡(精裝)
# 29  DEAHR5-A900BNA9W                                   KOKUYO 開學文具組-綠
# 30  DEAHR5-A900BNA9F                                   KOKUYO 開學文具組-粉
# 31  DEAHXL-A9008QDGC                                       LEGO積木文具組A
# 32  DEAH6R-A900B3VJE                              PLUS team-demi磁吸文具組
# 33  DEAE9F-A9008VLIA                                          桌上文具收納盒
# 34  DICKA0-A900B4LU9                                          彩色圖騰文具盒
# 35  QABH04-B900A9SD6                                      新人文具包 (60份)
# 36  DEAHR5-A900BNA9R                                   KOKUYO 開學文具組-藍
# 37  DSACMT-A90063A01                                  炎洲文具膠帶-18mmX45Y
# 38  QFAM2V-A9006C2RV                             文具筒台燈(ZE-9-1~ZE-9-5)
# 39  DEAH4D-A67993156                                        文具膠帶台 -1入
# 40  DEAHEE-A900ACAD4                                     15公分文具尺-2PCS
# 41  DEAHEE-A900ACAE6                                     60公分文具尺-1PCS
# 42  DEAHEE-A900C0OO7                                     30公分文具尺-4PCS
# 43  DEBAQX-B900BAQT8                                          木製文具收納盒
# 44  CCAA46-B39912565                                          專用文具鍵盤架
# 45  DJAH0H-A90057SJG                                          京都的文具時光
# 46  QFBU8V-A9009LPY2                                      文具店 TAG 裹葉色
# 47  QFBU0J-A900AGL0N        1組四入 日常計畫備忘貼 便利貼 標籤貼 N次貼 便條紙 辦公文具 開學文具 文具
# 48  QFAD4Y-A900ASCP1           【FL生活+】桌面抽屜式多功能文件文具收納盒系列-文具收納款(YG-069)
# 49  QFBU0Z-A900AG731  1組四入 快樂麋鹿中性筆 針管筆 0.35mm 黑色 原子筆 文具 開學文具 辦公文具 聖誕節
