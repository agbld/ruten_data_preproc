# %%
from tqdm import tqdm
import numpy as np
import pandas as pd
import jieba
import re
import import_ipynb
from cilin_lexicon_v2 import OutPutLexicon
# Out:
# importing Jupyter notebook from cilin_lexicon_v2.ipynb

# %% [markdown]
# #### Step 1 - Load data

# %%
# # load test query
# test_query_df = pd.read_csv('../../../../../PChome_datasets/search/pchome_test_collection/round1/test_query/test_query_250.csv')

# load valid query
test_query_df = pd.read_csv('../../../../../PChome_datasets/search/pchome_test_collection/round1/valid_query/valid_query_200.csv')

# product item
item_df = pd.read_parquet('../../../../../PChome_datasets/search/pchome_test_collection/round0/product_collection/product_collection_lg.parquet')

# %% [markdown]
# #### load cilin lexicon

# %%
# generate lexicon txt file

# oplex = OutPutLexicon('cilin_labeled_data_.json')
# class_name = oplex.start()

# %%
# class_name = ['brand','name','type','p-other']
class_name = ['type','brand','p-other']
for each_name in class_name:
    jieba.load_userdict('./Lexicon_merge/{}.txt'.format(each_name))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\EE303\AppData\Local\Temp\jieba.cache
# Loading model cost 0.311 seconds.
# Prefix dict has been built successfully.

# %% [markdown]
# #### Step 2 - Build model

# %% [markdown]
# #### model one

# %%
# 1. jieba tokenizer
def jieba_tokenizer(x):
    tokens = jieba.lcut(x, cut_all=False)
    stop_words = ['【','】','/','~','＊','、','（','）','+','‧',' ','']
    tokens = [t for t in tokens if t not in stop_words]
    return tokens

# %%
jieba_tokenizer('3090')
# Out:
# ['3090']

# %%
#Import TfIdfVectorizer from the scikit-learn library
from sklearn.feature_extraction.text import TfidfVectorizer

#Define a TF-IDF Vectorizer Object. Remove all english stopwords
tfidf = TfidfVectorizer(token_pattern=r"(?u)\b\w\w+\b", tokenizer=jieba_tokenizer, ngram_range=(1,2))

#Replace NaN with an empty string
#item_tokens_df['tokens'] = item_tokens_df['tokens'].fillna('')
item_df['name'] = item_df['name'].fillna('')
# Out:
# c:\Users\EE303\anaconda3\envs\pytorch_gpu\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#Construct the required TF-IDF matrix by applying the fit_transform method on the overview feature
tfidf_matrix = tfidf.fit_transform(item_df['name'])
#Output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (2252390, 5197395)

# %% [markdown]
# #### model two

# %%
# #Define a TF-IDF Vectorizer Object. Remove all english stopwords
# tfidf = TfidfVectorizer(token_pattern=r"(?u)\b\w\w+\b", tokenizer=jieba_tokenizer, ngram_range=(1,2))

#Define a TF-IDF Vectorizer Object. Remove all english stopwords
tfidf_char = TfidfVectorizer(token_pattern=r"(?u)\b\w\w+\b", analyzer='char')

# %%
#Construct the required TF-IDF matrix by applying the fit_transform method on the overview feature
tfidf_matrix_char = tfidf_char.fit_transform(item_df['name'])
#Output the shape of tfidf_matrix
tfidf_matrix_char.shape
# Out:
# (2252390, 8156)

# %% [markdown]
# #### Step 3 - Search function

# %%
from sklearn.metrics.pairwise import cosine_similarity
def search(query):
    score = np.zeros(tfidf_matrix.shape[1])
    que_tfidf = tfidf.transform([query]) # sparse array
    scores = cosine_similarity(que_tfidf,tfidf_matrix)
    top_50_indices = np.argsort(-scores[0])[:50]
    sum_of_score = sum(scores[0])
    # print("sum_of_score: ", sum_of_score)
    
    # if sum_of_score < 15 then using model two search again
    if sum_of_score < 10 : 
    # if True : 
        # print('using model 2')
        que_tfidf = tfidf_char.transform([query]) # sparse array
        scores = cosine_similarity(que_tfidf,tfidf_matrix_char)
        top_50_indices = np.argsort(-scores[0])[:50]
        sum_of_score = sum(scores[0])
        
        return sum_of_score, top_50_indices
    
    return sum_of_score, top_50_indices

# %%
# query = test_query_df.iloc[112]['query']
# query = test_query_df.iloc[225]['query']
# query = test_query_df.iloc[225]['query']
query = '禮物'

# %%
sum_of_score, top_50_indices = search(query)
print("query: ", query)
print("sum_of_score: ", sum_of_score)
item_df.loc[top_50_indices]
# Out:
# query:  禮物
# sum_of_score:  297.5381864694536
#                   item_id                                    name
# 339451   DJAM1W-A900B2KBD                                      禮物
# 122351   DJAF0D-A79759704                                    交換禮物
# 1443509  QFCD6S-D9009ON3L                                 禮物（電子書）
# 1111037  DNAA3W-A60228716                                 禮物  DVD
# 667754   DJAF06-A900AEN3X                                  禮物(精裝)
# 825342   DJAM07-A26949851                                   天使的禮物
# 893188   DJAM05-A9005CN84                                    天使禮物
# 948980   DJAF0D-A9007OYIU                                   最後的禮物
# 705705   DJAM0H-A90094LUA                                   先生的禮物
# 2209387  DJAH0H-A9007TZ5G                                   永恆的禮物
# 233239   DEAS3A-A900AFJFU   [Hutte vie] 電視造型手機放大器 逗趣禮物 交換禮物 聖誕節禮物
# 2223449  DJAM0W-A50370959                                    七個禮物
# 1602978  DJAM05-A900B2D8X                                   上帝的禮物
# 1606350  DJAF06-A900AAAJ7                                   夏天的禮物
# 2081980  DEAJ46-A51379285   ＊流行E線＊【B8019】情人禮物~~裸空丁字褲~猛男情趣生日禮物新婚禮物
# 1519034  DEAJ46-A55479130  ＊流行E線＊【B125】情人禮物~~金色漆皮丁字褲~猛男情趣生日禮物新婚禮物
# 1426340  DJAF2L-A62313638                                生日禮物(精裝)
# 1030940  DJAF0D-A60725291                                  聖誕節的禮物
# 452324   DJAP47-A74974502                                  不完美的禮物
# 202201   DJAD3J-A55724243                                   皮皮的禮物
# 1579318  DIBMUZ-A900B1ASZ      時尚商務電腦公事文件包/交換禮物/聖誕節禮物/贈品/禮物/電腦文件包
# 910961   DJAF07-A38917651                                  最幸福的禮物
# 2016937  QFCD0S-D9009UWWJ                               甜蜜禮物（電子書）
# 1262755  DJAF2L-A9009Z1FG                                   小狼的禮物
# 1797282  QFCD5B-D9009YP6P                              人生的禮物（電子書）
# 2213137  DJAP4E-A67746734                                超級禮物（精裝）
# 1841916  DJAF06-A900A6J83                               幸福的禮物(精裝)
# 821665   DJAM1W-A52465297                               天使的禮物(平裝)
# 389528   DJAF0D-A9008FM3G                                  交換禮物桌遊
# 320760   DJAM0H-A72571064                                   第三個禮物
# 1893285  DJAM1X-A50912542                               最後的禮物(平裝)
# 224663   DNAA3B-A9009GOHA                               最後的禮物 DVD
# 1429449  DEBAO3-A900C29AR            【OFFO歐楓】動物造型可愛面紙盒/交換禮物/聖誕節禮物
# 842511   DJAF06-A9005NF3F                                 神秘的生日禮物
# 968102   QFCD2O-D90099JNJ                               島嶼禮物（電子書）
# 1229518  DNAA1M-A9005HU0H                                神的禮物 DVD
# 384057   DJAM0H-A50831210                                 聖誕老人的禮物
# 1649305  DJAH1A-A62376178          最後的禮物                        全
# 412669   DJAF06-A9009N8ER                                誰的禮物(精裝)
# 1345480  DJAP4E-A9007A0WS                                禮物計畫(精裝)
# 794689   DJAP03-A53207052                               改變的禮物(平裝)
# 1120711  DJAF06-A47186095                               最美的禮物(精裝)
# 995053   DJAD3J-A56512663                                 爺爺的生日禮物
# 1814854  QFAM5W-A900A4SMI             半島良品 音樂雪人小夜燈 聖誕禮物 交換禮物 生日禮物
# 1260234  DJAF06-A900ABYDT                               最愛的禮物(精裝)
# 681102   DNAA6A-A9008BL4O                              天才的禮物  DVD
# 302392   DNAA35-A9009TP2U                                七個禮物 DVD
# 404631   QFCD68-D900APY9W                              夏天的禮物（電子書）
# 2088584  DJAM0V-A38975965                                山的禮物(平裝)
# 426824   DJBNB7-D900BAR3C                            禮物（有聲書）（電子書）

# %% [markdown]
# #### Step 4 - Output search results for test queries

# %%
for i, r in tqdm(enumerate(test_query_df.iloc)):
    query = r['query']
    sum_of_score, top_50_indices = search(query)
    results = item_df.loc[top_50_indices]
    # results = results.drop('sign_id', axis=1).reset_index(drop=True)

    # save result files for pooling step(id start from 250)
    results.to_parquet('./results/results_round1_valid_query/result_'+str(r['query_id']).zfill(3)+'.parquet')
# Out:
# 200it [06:28,  1.94s/it]

# %% [markdown]
# #### Sanbox

# %%
N = 0
print("query: ",test_query_df.iloc[N]['query'])
top_50 = pd.read_parquet('./results/results_round1_valid_query/result_'+str(N).zfill(3)+'.parquet')
top_50
# Out:
# query:  文具
#                   item_id                                             name
# 562018   DJAH0H-A75182816                  文具病：愛文具、玩文具、品文具，以文具傳達生活態度的25種可能
# 1274449  DEAHM3-A9007H88Q                                            文具置物盤
# 762168   DJAF0D-A76754434                                            文具精靈國
# 712380   DJAH0H-A9007LDDB                                文具手帖：台灣文具屋散策（熄燈號）
# 648737   DJAH2O-A9005N6QJ                             趣味文具大集合 VOL.30：文具的快樂
# 622818   DJAH2O-A9007YQWI                              趣味文具大集合 VOL.41：文具贈禮
# 1306687  DJAH2O-A9005511R                            文具設計造型完全圖鑑 NO.10：文具物語
# 1875355  DSACSD-A9007FT7F                                          文具膠帶3/4
# 203575   DJAP06-A9007KZYS                               文具手帖（1～4）文具好朋友勸敗套書
# 488678   QFCD25-D900915XV                           文具手帖（熄燈號）：臺灣文具屋散策（電子書）
# 1889928  CCAA46-B39912565                                          專用文具鍵盤架
# 1668611  DJAH0H-A9008A35F                                文具的品格：全球經典文具的深度巡禮
# 1177395  DJAP06-A9007L011                               文具手帖（5～8）文具偏執狂必藏套書
# 2093540  DJAH0H-A82260802                            文具手帖Season04：好色文具強迫症！
# 1228319  DJAH2O-A9006F0IA                                文具王高?正幸究極文具插畫圖鑑手冊
# 161955   DEAH4D-A67993156                                        文具膠帶台 -1入
# 1062002  DEAHR7-A900AXGV2                [O-life] 文具整理收納盒 辦公桌面整理 文具收納組 置物盒
# 1070195  QFCD25-D900915ZA                      文具手帖Season 04：好色文具強迫症！（電子書）
# 2027593  CCAA1W-A08435239                                      【創意生活】文具鍵盤架
# 1737928  DJAH0H-A9008A35D                              文具上手：12位專業人士活用文具的靈光
# 1100915  DJAH0H-A90057SJG                                          京都的文具時光
# 2036775  DEAH8Z-A900ASKDJ                S-8282文具整理收納盒 二入組(旋轉筆筒 文具收納 桌面整理)
# 438940   DJAM0H-A68469142                                           戀：文具物語
# 2014893  DJAF06-A900B80NF                                        文具大逃亡(精裝)
# 1874143  DJAH0H-A900A9T3K  文房具解剖圖鑑：23款經典文具「進化論」，圖解文具的構造、形狀、演變歷程，譜出浪漫文具文化史！
# 2172704  DEAH8Z-A900ASP5I              S-899文具整理收納盒 白色款+便利貼座(辦公桌面整理 文具收納組)
# 80907    DEAH8Z-A900ASP5M              S-899文具整理收納盒 藍色款+便利貼座(辦公桌面整理 文具收納組)
# 1021999  DEAH8Z-A900ASPLQ              S-898文具整理收納盒 白色款+便利貼座(辦公桌面整理 文具收納組)
# 142157   DEAH8Z-A900ASPLV              S-898文具整理收納盒 藍色款+便利貼座(辦公桌面整理 文具收納組)
# 661344   DEAH8Z-A900ASPTU              S-895文具整理收納盒 白色款+便利貼座(辦公桌面整理 文具收納組)
# 1994078  DEAH8Z-A900ASP6A              S-899文具整理收納盒 紅色款+便利貼座(辦公桌面整理 文具收納組)
# 1558085  DEAH8Z-A900ASR03              S-886文具整理收納盒 白色款+便利貼座(辦公桌面整理 文具收納組)
# 993215   DEAH8Z-A900ASPOD              S-897文具整理收納盒 白色款+便利貼座(辦公桌面整理 文具收納組)
# 1605154  DEAH8Z-A900ASQDZ              S-895文具整理收納盒 藍色款+便利貼座(辦公桌面整理 文具收納組)
# 79656    DEAH8Z-A900ASR1N              S-886文具整理收納盒 藍色款+便利貼座(辦公桌面整理 文具收納組)
# 1406264  DEAH8Z-A900ASPND              S-897文具整理收納盒 藍色款+便利貼座(辦公桌面整理 文具收納組)
# 1244617  DEAH8Z-A900ASPL6              S-898文具整理收納盒 紅色款+便利貼座(辦公桌面整理 文具收納組)
# 41095    DEAH8Z-A900ASPZV              S-895文具整理收納盒 紅色款+便利貼座(辦公桌面整理 文具收納組)
# 1241134  DEAH8Z-A900ASPO9              S-897文具整理收納盒 紅色款+便利貼座(辦公桌面整理 文具收納組)
# 1901398  DEAH8Z-A900ASP6J              S-899文具整理收納盒 灰色款+便利貼座(辦公桌面整理 文具收納組)
# 1611976  DEAH8Z-A900ASPLW              S-898文具整理收納盒 灰色款+便利貼座(辦公桌面整理 文具收納組)
# 449189   DEAH8Z-A900ASQEJ              S-895文具整理收納盒 灰色款+便利貼座(辦公桌面整理 文具收納組)
# 1230002  DEAH8Z-A900ASR1R              S-886文具整理收納盒 灰色款+便利貼座(辦公桌面整理 文具收納組)
# 373530   DEAH8Z-A900ASPNM              S-897文具整理收納盒 灰色款+便利貼座(辦公桌面整理 文具收納組)
# 775879   DEAHXL-A9008QDGC                                       LEGO積木文具組A
# 1788097  DEAH8Z-A900ASP5J              S-899文具整理收納盒 橘色款+便利貼座(辦公桌面整理 文具收納組)
# 2213991  QFCT08-A900A0I1G                                      自然簡約生活文具收納櫃
# 1215075  DJAH0H-A90080ZPM                    好文具帶來好生活！銀座?伊東屋文具 BETTER LIFE
# 1095008  DEAH8Z-A900ASQ23              S-895文具整理收納盒 橘色款+便利貼座(辦公桌面整理 文具收納組)
# 1982787  DEAH8Z-A900ASR1K              S-886文具整理收納盒 橘色款+便利貼座(辦公桌面整理 文具收納組)

# %%
for i in range(50):
    query = jieba_tokenizer(test_query_df.iloc[i]['query'])
    sum_of_score, top_50_indices = search(query)
    print(i, sum_of_score)
    if sum_of_score == 0:
        print(i," Document Not Found Error")

# %%
merge = []
for i in tqdm(item_df['name']):
    merge = list(set(merge + list(i)))

# %%
for i in range(10):
    print(test_query_df.iloc[i]['query'])
